# %%
import os

import pandas as pd

import numpy as np

import statistics as stat

df_1980 = pd.read_csv('CONUS_TGW_WRF_Historical\CONUS_TGW_WRF_Historical\AEC_WRF_Hourly_Mean_Meteorology_1980.csv')
 
print(df_1980)
# Out:
#                  Time_UTC      T2       Q2  SWDOWN     GLW  WSPD
# 0     1980-01-01 00:00:00  281.04  0.00462    0.00  323.63  3.11
# 1     1980-01-01 01:00:00  280.77  0.00461    0.00  324.25  3.13
# 2     1980-01-01 02:00:00  280.47  0.00459    0.00  322.99  3.44
# 3     1980-01-01 03:00:00  280.10  0.00456    0.00  320.40  3.80
# 4     1980-01-01 04:00:00  279.73  0.00454    0.00  316.27  4.13
# ...                   ...     ...      ...     ...     ...   ...
# 8779  1980-12-31 19:00:00  286.23  0.00366  587.80  262.31  4.04
# 8780  1980-12-31 20:00:00  286.62  0.00366  489.15  264.59  4.32
# 8781  1980-12-31 21:00:00  286.54  0.00375  344.53  266.39  4.51
# 8782  1980-12-31 22:00:00  285.19  0.00396  123.40  267.61  3.89
# 8783  1980-12-31 23:00:00  282.84  0.00397    0.00  265.71  3.31
#
# [8784 rows x 6 columns]

# %%
df_1980.corr()
# Out:
#               T2        Q2    SWDOWN       GLW      WSPD
# T2      1.000000  0.866108  0.430058  0.865402 -0.246454
# Q2      0.866108  1.000000  0.130503  0.920325 -0.296574
# SWDOWN  0.430058  0.130503  1.000000  0.147987  0.169511
# GLW     0.865402  0.920325  0.147987  1.000000 -0.177128
# WSPD   -0.246454 -0.296574  0.169511 -0.177128  1.000000

# %%
print(df_1980.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Time_UTC  8784 non-null   object
#  1   T2        8784 non-null   float64
#  2   Q2        8784 non-null   float64
#  3   SWDOWN    8784 non-null   float64
#  4   GLW       8784 non-null   float64
#  5   WSPD      8784 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 411.9+ KB
# None

# %%
print(df_1980["GLW"].mean)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0       323.63
# 1       324.25
# 2       322.99
# 3       320.40
# 4       316.27
#          ...
# 8779    262.31
# 8780    264.59
# 8781    266.39
# 8782    267.61
# 8783    265.71
# Name: GLW, Length: 8784, dtype: float64>

# %%
stat.mean(df_1980["GLW"])
# Out:
# 345.50134107468125

# %%
df_1980.plot()
# Out:
# <AxesSubplot:>

# %%
df_1980.plot(kind = 'scatter', x = 'Time_UTC', y = 'GLW')
# Out:
# <AxesSubplot:xlabel='Time_UTC', ylabel='GLW'>
